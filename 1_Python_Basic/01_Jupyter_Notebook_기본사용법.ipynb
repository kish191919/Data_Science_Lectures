# %% [markdown]
# ## 1. Jupyter_Notebook_기본사용법

# %% [markdown]
# ### 1.1 명령모드
#
# - 셀지우기 : dd
# - 현재 선택된 셀 위로 셀 삽입 : a
# - 현재 선택된 셀 아래로 셀 삽입 : b
# - 현재 셀의 라인 보기 : l
# - 마크다운으로 변환 : m
# - 코드로 변환 : y

# %%
"python"
# Out:
# 'python'

# %%
"test"
# Out:
# 'test'

# %%
"science"
# Out:
# 'science'

# %% [markdown]
# ### 1.2 편집모드
#
# - ctrl + Enter : 코드 실행되고 행 이동이 없음
# - shift + Enter : 코드 실행되고 아래 행으로 이동
# - alt + Enter : 코드가 실행되고 아래 셀이 생성
#
# - tab : 자동완성
# - shift + tab : 내부정보 보기
# - ? + 실행 : 내보정보 보기
# - ?? + 실행 : 코드 소스를 보기

# %%
def sum(a, b):
    """ test docstring """
    return a + b

# %%
sum
# Out:
# <function __main__.sum(a, b)>

# %%
sum??

# %%
def sum(a, b):
    """
    test docstring
    """
    return a + b

# %%
sum?

# %%
sum??

# %%
sum(1, 3)
# Out:
# 4

# %% [markdown]
# ### 1.3 Markdown 사용법

# %% [markdown]
# #### 1.3.1 머릿말 heading `#`
#
# # Heading
# ## Heading
# ### Heading
# #### Heading
# ##### Heading

# %% [markdown]
# #### 1.3.2 인용 `>`, `>>`
#
# > python
# >> data science

# %% [markdown]
# #### 1.3.3 리스트 `-`, `*`
#
# - data1
# - data2
#     - data2-1
#     - data2-2
# - data3

# %% [markdown]
# #### 1.3.4 코드블럭
#
# `- list`
#
#
# ```
# - list1
# - list2
# ```

# %% [markdown]
# #### 1.3.5 링크link
#
# http://google.com
#
# `[구글](http://google.com)`
#
# [구글](http://google.com)

# %% [markdown]
# #### 1.3.6 가로선 긋기
#
# `---`
#
# ---

# %% [markdown]
# ### 1.4 Magic Command 사용법

# %% [markdown]
# #### 1.4.1 `%`
# - %(cmd) : 한줄 수행
# - %%(cmd) : 셀 단위 수행
# - %(cmd)? : 커멘드에대한 설명

# %%
# %pwd
# Out:
# '/Users/sunghwanki/Desktop/2_Project/Data_Science_Lecture/1_Python_Basic'

# %%
# %ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb

# %%
# 만들어진 변수를 보여줌
# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# sum        function    <function sum at 0x7f95ed450a60>

# %%
a = 1

# %%
a
# Out:
# 1

# %%
# %whos
# Out:
# Variable   Type        Data/Info
# --------------------------------
# a          int         1
# sum        function    <function sum at 0x7f95ed450a60>

# %%
a = "python"

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %%
# %%time
1 + 3
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 5.01 µs
# 4

# %%
# %%timeit
1 + 3
# Out:
# 8.01 ns ± 0.251 ns per loop (mean ± std. dev. of 7 runs, 100000000 loops each)

# %%
# %%writefile test.py
print(2 + 3)
# Out:
# Writing test.py

# %%
# %ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb
# test.py

# %%
# %run test.py
# Out:
# 5

# %%
# %load test.py
print(2 + 3)

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %colors  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %man  %matplotlib  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# %%!  %%HTML  %%SVG  %%bash  %%capture  %%debug  %%file  %%html  %%javascript  %%js  %%latex  %%markdown  %%perl  %%prun  %%pypy  %%python  %%python2  %%python3  %%ruby  %%script  %%sh  %%svg  %%sx  %%system  %%time  %%timeit  %%writefile
#
# Automagic is ON, % prefix IS NOT needed for line magics.

# %% [markdown]
# #### 1.4.2 Shell Command

# %%
# !ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb
# test.py

# %%
! echo "python"
# Out:
# python

# %%
! touch data.py

# %%
! ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb
# data.py
# test.py

# %%
file_list = ! ls

# %%
file_list
# Out:
# ['00_Python 작업환경 구축.ipynb',
#  '01_Jupyter_Notebook_기본사용법.ipynb',
#  'data.py',
#  'test.py']

# %%
! echo {file_list}
# Out:
# [00_Python 작업환경 구축.ipynb, 01_Jupyter_Notebook_기본사용법.ipynb, data.py, test.py]

# %%
! cat test.py
# Out:
# print(2 + 3)

# %%
! mkdir python

# %%
! ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb
# data.py
# python
# test.py

# %%
! rmdir python

# %%
! ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb
# data.py
# test.py

# %%
! cp test.py test2.py

# %%
! ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb
# data.py
# test.py
# test2.py

# %%
! cat test2.py
# Out:
# print(2 + 3)

# %%
! rm test2.py

# %%
! ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb
# data.py
# test.py

# %%
! mv test.py python.py

# %%
! ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb
# data.py
# python.py

# %%
! df -h
# Out:
# Filesystem       Size   Used  Avail Capacity iused      ifree %iused  Mounted on
# /dev/disk1s5s1  466Gi   14Gi  237Gi     6%  553781 4881899059    0%   /
# devfs           193Ki  193Ki    0Bi   100%     668          0  100%   /dev
# /dev/disk1s4    466Gi  1.0Gi  237Gi     1%       2 4882452838    0%   /System/Volumes/VM
# /dev/disk1s2    466Gi  487Mi  237Gi     1%    2397 4882450443    0%   /System/Volumes/Preboot
# /dev/disk1s6    466Gi  5.8Mi  237Gi     1%      19 4882452821    0%   /System/Volumes/Update
# /dev/disk1s1    466Gi  212Gi  237Gi    48% 2188732 4880264108    0%   /System/Volumes/Data
# map auto_home     0Bi    0Bi    0Bi   100%       0          0  100%   /System/Volumes/Data/home

# %%
! ps
# Out:
#   PID TTY           TIME CMD
#  3043 ttys000    0:00.09 -bash
#  3548 ttys000    0:14.17 /Users/sunghwanki/anaconda3/bin/python /Users/sunghwan
#  4533 ttys001    0:00.40 -bash

# %% [markdown]
# ---
# ```
# (1) 아래 코드가 작성된 test.py 파일 생성 %%writefile
#     def sum(a, b):
#         return a + b
# (2) test.py가 생성되었는지 확인
# (3) test.py를 python.py로 변경
# (4) python.py를 test.py로 복사
# (5) test.py 파일 로드
# (6) test.py 실행 (run 명령어 사용 또는 호출된 코드 실행)
# (7) python.py 파일 삭제
# (8) sum(1, 2) 실행
# (9) sum(1, 2) 코드 실행시간 확인
# (10) 현재 선언된 변수 확인
# (11) a = 1 변수 선언
# (12) 선언된 변수 삭제
# (13) 선언된 변수가 삭제되었는지 확인
# ```

# %%
# %%writefile test.py
def sum(a, b):
    return a + b
# Out:
# Writing test.py

# %%
! cat test.py
# Out:
# def sum(a, b):
#     return a + b

# %%
! ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb
# data.py
# python.py
# test.py

# %%
! mv test.py python.py

# %%
! ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb
# data.py
# python.py

# %%
! cat python.py
# Out:
# def sum(a, b):
#     return a + b

# %%
! cp python.py test.py

# %%
! ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb
# data.py
# python.py
# test.py

# %%
! cat test.py
# Out:
# def sum(a, b):
#     return a + b

# %%
# %load test.py
def sum(a, b):
    return a + b

# %%
# %run test.py

# %%
! rm python.py

# %%
! ls
# Out:
# 00_Python 작업환경 구축.ipynb
# 01_Jupyter_Notebook_기본사용법.ipynb
# data.py
# test.py

# %%
sum(1, 2)
# Out:
# 3

# %%
# %%timeit
sum(1, 2)
# Out:
# 112 ns ± 10.7 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %whos
# Out:
# Variable    Type        Data/Info
# ---------------------------------
# file_list   SList       ['00_Python 작업환경 구축.ipynb<...>b', 'data.py', 'test.py']
# sum         function    <function sum at 0x7f95ed598ea0>

# %%
a = 1

# %%
# %whos
# Out:
# Variable    Type        Data/Info
# ---------------------------------
# a           int         1
# file_list   SList       ['basic_syntax.ipynb', 'd<...>jn_dss.ipynb', 'test.py']
# sum         function    <function sum at 0x10a7c6ae8>

# %%
# %reset
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? y

# %%
# %whos
# Out:
# Interactive namespace is empty.

# %% [markdown]
# ##### expression

# %%
result = 1 + 3

# %%
result * 2
# Out:
# 8

# %%
1 + 3
# Out:
# 4

# %%
_ * 2
# Out:
# 8

# %%
"python"
# Out:
# 'python'

# %%
_ + " test"
# Out:
# 'python test'

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
